# %%
import pandas as pd

# Sample student score dataset
data = {
    "Student_ID": [101, 102, 103, 104, 105],
    "Name": ["Rahul", "Priya", "Arjun", "Sneha", "Kiran"],
    "Maths": [85, 90, 78, 88, 95],
    "Science": [80, 92, 75, 85, 91],
    "English": [78, 88, 82, 90, 87]
}

df = pd.DataFrame(data)
df.to_csv("student_scores.csv", index=False)
print("student_scores.csv created successfully!")
# Out:
# student_scores.csv created successfully!

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("student_scores.csv")

# Display first 5 rows
print("First 5 Rows:")
print(df.head())

# Display last 5 rows
print("\nLast 5 Rows:")
print(df.tail())

# Display dataset shape
print("\nDataset Shape:")
print(df.shape)

# Display column names
print("\nColumns:")
print(df.columns)

# Display dataset information
print("\nDataset Information:")
df.info()

# Display summary statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# First 5 Rows:
#    Student_ID   Name  Maths  Science  English
# 0         101  Rahul     85       80       78
# 1         102  Priya     90       92       88
# 2         103  Arjun     78       75       82
# 3         104  Sneha     88       85       90
# 4         105  Kiran     95       91       87
#
# Last 5 Rows:
#    Student_ID   Name  Maths  Science  English
# 0         101  Rahul     85       80       78
# 1         102  Priya     90       92       88
# 2         103  Arjun     78       75       82
# 3         104  Sneha     88       85       90
# 4         105  Kiran     95       91       87
#
# Dataset Shape:
# (5, 5)
#
# Columns:
# Index(['Student_ID', 'Name', 'Maths', 'Science', 'English'], dtype='str')
#
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  5 non-null      int64
#  1   Name        5 non-null      str
#  2   Maths       5 non-null      int64
#  3   Science     5 non-null      int64
#  4   English     5 non-null      int64
# dtypes: int64(4), str(1)
# memory usage: 332.0 bytes
#
# Summary Statistics:
#        Student_ID      Maths    Science    English
# count    5.000000   5.000000   5.000000   5.000000
# mean   103.000000  87.200000  84.600000  85.000000
# std      1.581139   6.300794   7.231874   4.898979
# min    101.000000  78.000000  75.000000  78.000000
# 25%    102.000000  85.000000  80.000000  82.000000
# 50%    103.000000  88.000000  85.000000  87.000000
# 75%    104.000000  90.000000  91.000000  88.000000
# max    105.000000  95.000000  92.000000  90.000000
